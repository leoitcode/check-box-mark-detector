# %% [markdown]
# # Checkbox and checkmark recognition
#
# Tensorflow v2.7.0
# Keras v2.7.0

# %% [markdown]
# # Installation Packages

# %%
# !poetry add numpy && poetry add tensorflow
# Out:
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   • numpy
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Nothing to add.
# Using version ^2.7.0 for tensorflow
#
# Updating dependencies
# Resolving dependencies... (56.7s)Resolving dependencies... (5.2s)Resolving dependencies... (20.5s)Resolving dependencies... (36.5s)Resolving dependencies... (44.6s)
#
# Writing lock file
#
# Package operations: 37 installs, 0 updates, 0 removals
#
#   • Installing certifi (2021.10.8): Pending...
#   • Installing charset-normalizer (2.0.10): Pending...
#   • Installing idna (3.3): Pending...
#   • Installing pyasn1 (0.4.8): Pending...
#   • Installing urllib3 (1.26.8): Pending...
#   • Installing charset-normalizer (2.0.10): Pending...
#   • Installing idna (3.3): Pending...
# ...

# %%
# !yay -S tree

# %% [markdown]
# # Initial Imports and Configuration

# %%
from pathlib import Path
from shutil import copyfile

# %% [markdown]
# # Data Understanding & Directory Configuration

# %%
path = Path(Path.cwd().parents[0], "dataset", "dataset-mleng-exercise")

# %%
# !ls
# Out:
# editor-0  editor-1

# %%
# %cd ../dataset/dataset-mleng-exercise
# Out:
# [Errno 2] No such file or directory: '../dataset/dataset-mleng-exercise'
# /home/leobit/Development/learn/check-box-mark-detector/dataset/dataset-mleng-exercise

# %%
# !tree
# Out:
# .
# ├── editor-0
# │   ├── {00062724-39F0-259E-9BB0-F7C2EC60DE0A}.pdf.results
# │   │   ├── checkbox-01.checked.png
# │   │   ├── checkbox-02.open.png
# │   │   ├── checkbox-03.open.png
# │   │   ├── checkbox-04.open.png
# │   │   ├── checkbox-05.checked.png
# │   │   ├── checkbox-06.open.png
# │   │   ├── checkbox-07.open.png
# │   │   ├── checkbox-08.checked.png
# │   │   ├── checkbox-09.open.png
# │   │   ├── checkbox-10.open.png
# │   │   ├── checkbox-11.checked.png
# │   │   ├── checkbox-12.open.png
# │   │   ├── checkbox-13.open.png
# │   │   ├── checkbox-14.open.png
# │   │   └── checkbox-15.open.png
# │   ├── {00063398-CF7A-13D8-FFBD-2DCDC421E287}.pdf.results
# │   │   ├── checkbox-01.checked.png
# │   │   ├── checkbox-02.open.png
# │   │   ├── checkbox-03.open.png
# │   │   ├── checkbox-04.checked.png
# │   │   ├── checkbox-05.open.png
# │   │   ├── checkbox-06.checked.png
# │   │   ├── checkbox-07.open.png
# │   │   ├── checkbox-08.open.png
# ...

# %%
for p in _path.rglob('*'):
    print()

# %%
def down_to_files(_path):
    while True:
        for p in _path.rglob('*'):
            if p.is_dir():
                new_path = _path / p
                down_to_files(new_path)
            if p.is_file():
                yield _path.glob('*.png')

# %%
next(down_to_files(path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/lib/python3.9/pathlib.py:1439, in Path.is_dir(self)
#    1438 try:
# -> 1439     return S_ISDIR(self.stat().st_mode)
#    1440 except OSError as e:
#
# File /usr/lib/python3.9/pathlib.py:1232, in Path.stat(self)
#    1228 """
#    1229 Return the result of the stat() system call on this path, like
#    1230 os.stat() does.
#    1231 """
# -> 1232 return self._accessor.stat(self)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/leobit/Development/learn/check-box-mark-detector/dataset/dataset/dataset-mleng-exercise'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <module>
# ----> 1 next(down_to_files(path))
#
# Input In [31], in down_to_files(_path)
# ...

# %%
def down_to_files(_path):
    for p in _path.glob('*'):
        if p.is_dir():
            new_path = _path / p
            down_to_files(new_path)
        if p.is_file():
            yield _path.glob('*.png')
            

for p in _path.glob('*'):
    
    if p.is_dir():
        new_path = _path / p
        
    if p.is_dir():
# Out:
# /home/leobit/Development/learn/check-box-mark-detector/dataset/dataset-mleng-exercise/editor-1/{00B63699-CED2-58CC-DCA0-A1BA75E600D0}.pdf.results/checkbox-01.not-checkbox.png
# /home/leobit/Development/learn/check-box-mark-detector/dataset/dataset-mleng-exercise/editor-1/{00B63699-CED2-58CC-DCA0-A1BA75E600D0}.pdf.results/._checkbox-01.not-checkbox.png
# /home/leobit/Development/learn/check-box-mark-detector/dataset/dataset-mleng-exercise/editor-1/{00C64222-D0BC-FC13-7AAE-9D806BAC5CFF}.pdf.results/._checkbox-01.checked.png
# /home/leobit/Development/learn/check-box-mark-detector/dataset/dataset-mleng-exercise/editor-1/{00C64222-D0BC-FC13-7AAE-9D806BAC5CFF}.pdf.results/checkbox-01.checked.png
# /home/leobit/Development/learn/check-box-mark-detector/dataset/dataset-mleng-exercise/editor-1/{00C64222-D0BC-FC13-7AAE-9D806BAC5CFF}.pdf.results/._checkbox-02.open.png
# ...

# %% [markdown]
# # Data Understading

# %% [markdown]
# # Data Processing

# %% [markdown]
# # Modeling

# %% [markdown]
# # Evaluation
